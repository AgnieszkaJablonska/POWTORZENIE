# %% [markdown]
# # Phyiscs Problems - Lectures 22 & 23 - Homework 10
#
# FALL 2024

# %% [markdown]
# ### 1) Altitude of a satellite
#
# A satellite is to be launched into a circular orbit around the Earth so that it orbits the planet once every T seconds.
#
# The altitude h above the Earth’s surface that the satellite must have is:
#
# $$h = \left( \frac{G M T^2}{4\pi^2} \right)^{1/3} - R$$
#
# where $G = 6.67 \times 10^{-11}$ m$^3$ kg$^{-1}$ s$^{-2}$
# is Newton's gravitational constant, $M = 5.97 \times 10^{24}$ kg is the mass of the Earth, and $R = 6371$ km is its radius.
#
# #### Write a function that asks the user to enter the desired value of T and then calculates and prints out the correct altitude in meters.

# %%
import numpy as np

G = 6.67 * 10**(-11)
M = 5.97 * 10**(24)
R = 6371*1000

def altitude(T):
    
    h = (((G*M*T**2)/(4*np.pi**(2)))**(1/3)) - R
    return h

# %% [markdown]
# Use your program to calculate the altitudes of satellites that orbit the Earth once
# a day (so-called “geosynchronous” orbit), once every 90 minutes, and once every
# 45 minutes. What do you conclude from the last of these calculations?

# %%
geosync = 3600 * 24
hourhalf = 60 * 90
min45 = 60 * 45
print("24 hours: Altitude =",altitude(geosync), "m", "; 90 min: Altitude =",altitude(hourhalf), "m",
      ";  45 min: Altitude =", altitude(min45), "m")
print("The conclusion is that the longer the period of time on the orbit the bigger the altitude")
# Out:
# 24 hours: Altitude = 35855910.17617497 m ; 90 min: Altitude = 279321.62537285965 m ;  45 min: Altitude = -2181559.8978108233 m
# The conclusion is that the longer the period of time on the orbit the bigger the altitude

# %% [markdown]
# Technically a geosynchronous satellite is one that orbits the Earth once persidereal
# day, which is 23.93 hours, not 24 hours. Why is this? And how much difference
# will it make to the altitude of the satellite?

# %%
persidereal = 3600 * 23.93
print("24 hours: Altitude =",altitude(geosync), "m", "; 23.93 hours: Altitude =",altitude(persidereal), "m" )
print("The difference in altidute comparing 24 hours and 23.93 hours is", altitude(geosync) - altitude(persidereal), "m")
# Out:
# 24 hours: Altitude = 35855910.17617497 m ; 23.93 hours: Altitude = 35773762.329895645 m
# The difference in altidute comparing 24 hours and 23.93 hours is 82147.8462793231 m

# %% [markdown]
# #### Modify your code to calculate the times from 0.5 hour  to 30 days, in steps of 0.5 hours.   Then plot those data points (time vs h) with properly labled axes.  Plot orbits with height below 0 as red, and plots positive heeghts with times less than geosynchronous in blue and those longer in green.

# %%
import matplotlib.pyplot as plt
t_height_less_than_0 = []
t_positive_heights_less_than_geosynchronous = []
t_positive_heights_longer_than_geosynchronous = []

t = np.arange(0.5*3600, 30*24*3600, 0.5*3600)
print(altitude(t))
for i in range(len(t)):
    if altitude(t[i]) <= 0:
        t_height_less_than_0.append(t[i])
    elif altitude(t[i]) >= 0 and altitude(t[i]) <= altitude(persidereal):
        t_positive_heights_less_than_geosynchronous.append(t[i])
    else:
        t_positive_heights_longer_than_geosynchronous.append(t[i])

plt.plot(np.array(t_height_less_than_0), altitude(np.array(t_height_less_than_0)), 'r')
plt.plot(np.array(t_positive_heights_less_than_geosynchronous), altitude(np.array(t_positive_heights_less_than_geosynchronous)), 'b')
plt.plot(np.array(t_positive_heights_longer_than_geosynchronous), altitude(np.array(t_positive_heights_longer_than_geosynchronous)), 'g')
plt.xlabel("Time [s]")
plt.ylabel("Height [m]")
plt.legend(["Height less than the radius of the Earth", "Height greater that the radius of the Earth & less than geosynchronous", 
            "Height greater that the radius of the Earth & greater than geosynchronous"], loc = "upper left")
plt.title("Time vs Height")
# Out:
# [-3.17385883e+06 -1.29585475e+06  2.79321625e+05 ...  4.00758893e+08
#   4.00947751e+08  4.01136565e+08]
# Text(0.5, 1.0, 'Time vs Height')

# %% [markdown]
# ### 2) Special Relativity
#
# A spaceship travels from Earth in a straight line at a (relativistic)
# speed $v$ to another planet $x$ light years away. Write a program to ask
# the user for the value of $x$ and the speed $v$ as a fraction of the speed
# of light, then print out the time in years that the spaceship takes to
# reach its destination (a) in the rest frame of an observer on Earth
# and (b) as perceived by a passenger on board the ship.
#
# $$x' = \gamma (x - vt)$$
#
# $$t' = \gamma \left(t - \frac{v x}{c^2}\right)$$
#
# $$\gamma = \frac{1}{\sqrt{1 - \frac{v^2}{c^2}}}$$

# %%
import numpy as np

c = 1  #speed of light in light years per year

def gamma(v):
    return(1/np.sqrt(1-(v**2)/(c**2)))
def t(x, v):
    return(x/v)
def t_prime(x, v):
    return(gamma(v)*(t(x, v) - (v*x/c**2)))
def x_prime(x, v, t):
    return(gamma(v)*(x - v*t))

print("Time in years that the spaceship takes to reach its destination in the rest frame of an observer on Earth is", t(10, 0.90*c), "for distance of 10 light years and velocuty v=0.90c")
print("Time in years that the spaceship takes to reach its destination as perceived by a pssenger on board the ship is", t_prime(10, 0.90*c),"for distance of 10 light years and velocuty v=0.90c")
print()
print("Time in years that the spaceship takes to reach its destination in the rest frame of an observer on Earth is", t(10, 0.98*c), "for distance of 10 light years and velocuty v=0.98c")
print("Time in years that the spaceship takes to reach its destination as perceived by a pssenger on board the ship is", t_prime(10, 0.98*c), "for distance of 10 light years and velocuty v=0.98c")
print()
print("Time in years that the spaceship takes to reach its destination in the rest frame of an observer on Earth is", t(10, 0.999*c), "for distance of 10 light years and velocuty v=0.999c")
print("Time in years that the spaceship takes to reach its destination as perceived by a pssenger on board the ship is", t_prime(10, 0.999*c), "for distance of 10 light years and velocuty v=0.999c")
# Out:
# Time in years that the spaceship takes to reach its destination in the rest frame of an observer on Earth is 11.11111111111111 for distance of 10 light years and velocuty v=0.90c
# Time in years that the spaceship takes to reach its destination as perceived by a pssenger on board the ship is 4.843221048378526 for distance of 10 light years and velocuty v=0.90c
#
# Time in years that the spaceship takes to reach its destination in the rest frame of an observer on Earth is 10.204081632653061 for distance of 10 light years and velocuty v=0.98c
# Time in years that the spaceship takes to reach its destination as perceived by a pssenger on board the ship is 2.0305866063400337 for distance of 10 light years and velocuty v=0.98c
#
# Time in years that the spaceship takes to reach its destination in the rest frame of an observer on Earth is 10.01001001001001 for distance of 10 light years and velocuty v=0.999c
# ...

# %% [markdown]
# #### Use your program to calculate the answers for a planet 10 light years away with $v = 0.90c$,  $v = 0.98c$, $v = 0.999c$.

# %% [markdown]
# ### 3) The quadratic equation
#
#  Write a program that takes as input three numbers, $a$, $b$, and $c$, and prints out the two solutions to the quadratic equation $ax^2 + bx + c = 0$ using the standard
# formula:
#
# $$x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}$$
#
# Use your program to compute the solutions of $0.001x^2 + 1000x + 0.001 = 0$.

# %%
import numpy as np

def quadratic(a, b, c):

    a = 0.001
    b = 1000
    c = 0.001
    
    # 0 = a*x**2 + b*c + c

    x1 = (-b - np.sqrt(b**2 - 4 * a*c))/ 2*a
    x2 = (-b + np.sqrt(b**2 - 4 * a*c))/ 2*a
    return x1, x2

root1,root2 = quadratic(0.001,1000,0.001)

print("The square roots of this quadratic equation are:", "x1=", root1, "x2=", root2 )
# Out:
# The square roots of this quadratic equation are: x1= -0.999999999999 x2= -9.999894245993345e-13

# %% [markdown]
# There is another way to write the solutions to a quadratic equation. Multiplying top and bottom of the solution above by $-b \mp \sqrt{b^2 - 4ac}$, show that the solutions
# can also be written as:
#
# $$x = \frac{2c}{-b \mp \sqrt{b^2 - 4ac}}$$
#
# Add further lines to your program to print these values in addition to the earlier ones and again use the program to solve $0.001x^2 + 1000x + 0.001 = 0$. What do you see? How do you explain it?

# %%
import numpy as np

def quadratic(a,b,c):

    a = 0.001
    b = 1000
    c = 0.001
    
    # 0 = a*x**2 + b*c + c

    x1 = (-b - np.sqrt(b**2 - 4 * a*c))/ 2*a
    x2 = (-b + np.sqrt(b**2 - 4 * a*c))/ 2*a
    return x1, x2

root1,root2 = quadratic(0.001,1000,0.001)

print("The square roots of this quadratic equation are:", "x1=", root1, "x2=", root2 )

a = 0.001
b = 1000
c = 0.001

x3 = root1 * (-b - np.sqrt(b**2 - 4*a*c))
x4 = root2 * (-b + np.sqrt(b**2 - 4*a*c))

print(x3, x4)

x5 = ((2*c)/(-b + np.sqrt(b**2 - 4*a*c)))
x6 = ((2*c)/(-b - np.sqrt(b**2 - 4*a*c)))

print(x5, x6)
# Out:
# The square roots of this quadratic equation are: x1= -0.999999999999 x2= -9.999894245993345e-13
# 1999.999999996 1.9999576986210164e-21
# -1000010.5755125057 -1.000000000001e-06

# %% [markdown]
# Using what you have learned, write a new program that calculates both roots of a quadratic equation accurately in all cases.
#
# __(NOTE: MANY Online quadratic equation are WRONG, so careful how you check!!!).__
